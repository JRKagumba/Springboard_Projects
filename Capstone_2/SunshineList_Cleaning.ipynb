# %% [markdown]
# # Sunshine List - Cleaning

# %% [markdown]
# All files were downloaded from the government of Ontario website [here](https://www.ontario.ca/page/public-sector-salary-disclosure#section-1)
#
#
# While downloading the necessary files from the website, I renamed the files to standardize the file names.<br>They all followed this format: '[Year]_Sunshine_Salaries.csv'

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import os
import re

# %% [markdown]
# ### Load Data into Dict

# %%
df_Dict={}

for Year in range(1996,2021):
    for entry in os.scandir(r'Raw_Files'):
        if (str(Year) in entry.path) and ('Addendum' not in entry.path):
            df_Dict[Year]= pd.read_csv(entry.path).dropna(axis =1, how ='all').dropna(axis =0, how = 'all')

# %% [markdown]
# ### Checking consitentcy in column names and position

# %%
Raw_ColNames={}

for i in range(7):
    Raw_ColNames[i]=[]
#Checking consistency in column names
for i in range(7):
    for Year in range(1996,2021):
        Raw_ColNames[i].append(df_Dict[Year].columns[i])

for i in range(7):
    print('Column {}-'.format(i+1),set(Raw_ColNames[i]))
# Out:
# Column 1- {'Sector'}
# Column 2- {'Last name', 'Last Name', 'Surname'}
# Column 3- {'First name', 'First Name'}
# Column 4- {'Salary paid', 'Salary Paid', 'Salary Paid '}
# Column 5- {'Taxable Benefits', 'Taxable benefits'}
# Column 6- {'Employer'}
# Column 7- {'Job title', 'Position', 'Job Title'}

# %% [markdown]
# Looks like all column names are in the right order but with different names

# %%
#Standardize column names
Clean_ColNames=['Sector','Last Name','First Name','Salary','Tax Benefits','Employer','Job Title','Year']

for Year in range(1996,2021):
    df_Dict[Year].columns=Clean_ColNames

# %% [markdown]
# ### Checking for missing values

# %%
for Year in range(1996,2021):
    if df_Dict[Year].isna().sum().any()>0:
        for column in Clean_ColNames:
            if df_Dict[Year][column].isna().sum()>0:
                print(Year)
                print(' [{}] missing values = {}'.format(column,df_Dict[Year][column].isna().sum()))
# Out:
# 1996
#  [First Name] missing values = 1
# 1997
#  [Job Title] missing values = 1
# 1998
#  [First Name] missing values = 1
# 2013
#  [First Name] missing values = 1
# 2016
#  [Tax Benefits] missing values = 1

# %% [markdown]
# Looks like there's only a few areas with missing data, I'll put them into a small data frame to take a look at them

# %%
df_MissingData=pd.DataFrame(columns=Clean_ColNames)    
    
for Year in range(1996,2021):
    if df_Dict[Year].isna().sum().any()!=0:
        for column in Clean_ColNames:
            if df_Dict[Year][column].isna().sum()>0:
                df_MissingData=df_MissingData.append(df_Dict[Year][df_Dict[Year][column].isna()],ignore_index=True)
                

df_MissingData
# Out:
#                           Sector  Last Name First Name        Salary  \
# 0                 MUNICIPALITIES   Yearwood        NaN   $116,371.00
# 1                 Crown Agencies     Walker        G J  $104,932.87
# 2                 Crown Agencies   DONNELLY        NaN   $100,813.00
# 3                 Crown Agencies         LI        NaN     108421.82
# 4  Other Public Sector Employers  Malenfant      James   $152,545.47
#
#   Tax Benefits                                 Employer  \
# 0      $978.00     Municipality of Metropolitan Toronto
# 1     $403.32                             Ontario Hydro
# 2   $21,526.00                            Ontario Hydro
# 3        47.18                         eHealth Ontario
# 4          NaN  Independent Electricity System Operator
#
#                                            Job Title  Year
# 0                 Deputy Commissioner of Corp. Serv.  1996
# 1                                                NaN  1997
# 2                     Mgr, Labour Reltns, IMO/CMO/N-  1998
# 3                    Privacy and Security Architect   2013
# 4  Senior Analyst - Compliance and Dispute Resolu...  2016

# %% [markdown]
# Make note that they're all 'NaN' when converting column data types into a string, I'll investigate this further and try to resolve it once I've concatenated all the years together.

# %% [markdown]
# ### Standardize the column data types
#
#
# Now to check and standardize the data types for all columns
# <br>This is the target end result for data types per column:
# <br>'Sector'--------->str
# <br>'Last Name'----->str
# <br>'First Name'---->str
# <br>'Salary'-------->str-->float
# <br>'Tax Benefits'-->str-->float
# <br>'Employer'------>str
# <br>'Job Title'----->str
# <br>'Year'--------->int

# %%
for Year in range(1996,2021):
    for column in df_Dict[Year].columns:
        if column == 'Year':
            try:
                df_Dict[Year][column].fillna(Year) #Fill in missing values with the year
                df_Dict[Year][column]=df_Dict[Year][column].astype(int)
            except ValueError:
                print("Trouble in {}'s data in the {} column".format(Year,column))
        else:
            try:
                df_Dict[Year][column]=df_Dict[Year][column].fillna(np.nan).astype(str)
            except ValueError:
                print("Trouble in {}'s data in the {} column".format(Year,column))
# Out:
# Trouble in 2016's data in the Year column

# %%
#Isolate affected rows
Affected_Rows=df_Dict[2016][df_Dict[2016]['Year'] != str(2016)]

Affected_Rows
# Out:
#                                        Sector   Last Name   First Name  \
# 6223                           Crown Agencies       Fagan       Thomas
# 9323                           Crown Agencies       Doran      Patrick
# 23040      Government of Ontario - Ministries     LeBlanc       Laurie
# 32225   Hospitals and Boards of Public Health       Levac      Jody J.
# 32238   Hospitals and Boards of Public Health    Mccarron  Veronica J.
# ...                                       ...         ...          ...
# 122148                           Universities    Weisener        Chris
# 122149                           Universities  Wellington      William
# 122152                           Universities    Williams         Mita
# 122165                           Universities          Wu     Qingming
# 122167                           Universities          Xu     Shi Jing
#
#              Salary Tax Benefits                          Employer  \
# 6223    $126,498.77        $0.00         Landlord and Tenant Board
# 9323    $121,415.63        $0.00           Social Benefits Tribuna
# 23040   $242,431.56   $23,569.27                 Municipal Affairs
# 32225   $169,367.20      $622.35  Southlake Regional Health Centre
# 32238   $133,124.22      $493.25  Southlake Regional Health Centre
# ...             ...          ...                               ...
# 122148  $135,388.56      $535.08             University of Windsor
# 122149  $233,108.08      $539.04             University of Windsor
# 122152  $129,848.16      $519.66             University of Windsor
# 122165  $157,097.76    $1,728.75             University of Windsor
# 122167  $142,341.12    $1,018.44             University of Windsor
#
#                                                 Job Title  \
# 6223                             Social Benefits Tribunal
# 9323     Child and Family Services Review Board and Cu...
# 23040                                             Housing
# 32225                                            Director
# 32238                                             Manager
# ...                                                   ...
# 122148                                Associate Professor
# 122149                                Associate Professor
# 122152                                      Librarian III
# 122165                                          Professor
# 122167                                          Professor
#
#                                                    Year
# 6223      Member (Part-time) / Membre (à temps partiel)
# 9323      Member (Part-time) / Membre (à temps partiel)
# 23040                                   Deputy Minister
# 32225    seconded to Stevenson Memorial Hospital as CEO
# 32238                   seconded to Cancer Care Ontario
# ...                                                 ...
# 122148                                       Researcher
# 122149                                  Program Advisor
# 122152                                        Preceptor
# 122165                            Canada Research Chair
# 122167                            Canada Research Chair
#
# [65 rows x 8 columns]

# %% [markdown]
# It looks like there are strings in the 'Year' column of the 2016 data. They seem to be part of the job title. I'll concatenate the cells where this is true in the 'Year' column to the 'Job Title' column.

# %%
#Concatenate strings from affected rows in 'Job Title' and 'Year'
Jobs_Concat=Affected_Rows['Job Title']+' '+Affected_Rows['Year']

#Replace new string in affected rows of 'Job Title Column'
for index,value in Jobs_Concat.items():
    df_Dict[2016].at[index,'Job Title']=value

#Check to make sure changes have been made to the dataframe
df_Dict[2016][df_Dict[2016]['Year'] != str(2016)]
# Out:
#                                        Sector   Last Name   First Name  \
# 6223                           Crown Agencies       Fagan       Thomas
# 9323                           Crown Agencies       Doran      Patrick
# 23040      Government of Ontario - Ministries     LeBlanc       Laurie
# 32225   Hospitals and Boards of Public Health       Levac      Jody J.
# 32238   Hospitals and Boards of Public Health    Mccarron  Veronica J.
# ...                                       ...         ...          ...
# 122148                           Universities    Weisener        Chris
# 122149                           Universities  Wellington      William
# 122152                           Universities    Williams         Mita
# 122165                           Universities          Wu     Qingming
# 122167                           Universities          Xu     Shi Jing
#
#              Salary Tax Benefits                          Employer  \
# 6223    $126,498.77        $0.00         Landlord and Tenant Board
# 9323    $121,415.63        $0.00           Social Benefits Tribuna
# 23040   $242,431.56   $23,569.27                 Municipal Affairs
# 32225   $169,367.20      $622.35  Southlake Regional Health Centre
# 32238   $133,124.22      $493.25  Southlake Regional Health Centre
# ...             ...          ...                               ...
# 122148  $135,388.56      $535.08             University of Windsor
# 122149  $233,108.08      $539.04             University of Windsor
# 122152  $129,848.16      $519.66             University of Windsor
# 122165  $157,097.76    $1,728.75             University of Windsor
# 122167  $142,341.12    $1,018.44             University of Windsor
#
#                                                 Job Title  \
# 6223     Social Benefits Tribunal Member (Part-time) /...
# 9323     Child and Family Services Review Board and Cu...
# 23040                             Housing Deputy Minister
# 32225   Director  seconded to Stevenson Memorial Hospi...
# 32238            Manager  seconded to Cancer Care Ontario
# ...                                                   ...
# 122148                    Associate Professor  Researcher
# 122149               Associate Professor  Program Advisor
# 122152                           Librarian III  Preceptor
# 122165                   Professor  Canada Research Chair
# 122167                   Professor  Canada Research Chair
#
#                                                    Year
# 6223      Member (Part-time) / Membre (à temps partiel)
# 9323      Member (Part-time) / Membre (à temps partiel)
# 23040                                   Deputy Minister
# 32225    seconded to Stevenson Memorial Hospital as CEO
# 32238                   seconded to Cancer Care Ontario
# ...                                                 ...
# 122148                                       Researcher
# 122149                                  Program Advisor
# 122152                                        Preceptor
# 122165                            Canada Research Chair
# 122167                            Canada Research Chair
#
# [65 rows x 8 columns]

# %% [markdown]
# The 'Job Title' column looks to be in good shape now.
# <br> <br>'ll check out the 'Year' column in all the dataframes now to make sure that they're consitent.

# %%
#Replace all the values in the 'Year' column with int 2016
df_Dict[2016]['Year']=2016 

#Checking out the 'Year' column in all the dataframes
for Year in range(1996,2021):
    print(Year, set(df_Dict[Year]['Year']))
# Out:
# 1996 {1996}
# 1997 {1997}
# 1998 {1998}
# 1999 {1999}
# 2000 {2000}
# 2001 {2001}
# 2002 {2002}
# 2003 {2003}
# 2004 {2004}
# 2005 {2005}
# 2006 {2006}
# 2007 {2007}
# 2008 {2008}
# 2009 {2009}
# 2010 {2010}
# 2011 {2011}
# 2012 {2012}
# 2013 {2013}
# 2014 {2014}
# 2015 {2016, 2017, 2018, 2015}
# 2016 {2016}
# 2017 {2017}
# 2018 {2018}
# 2019 {2019}
# 2020 {2020}

# %% [markdown]
# Looks like 2015 has a few different values in the 'Year' column

# %%
df_Dict[2015][df_Dict[2015]['Year'] != 2015]
# Out:
#                                Sector  Last Name  First Name       Salary  \
# 76671                    Universities       Webb        Paul  $105,001.75
# 111692  Other Public Sector Employers        Yue       Jenny  $114,158.53
# 113433  Other Public Sector Employers  Macdonald   Christine  $100,789.02
# 113434  Other Public Sector Employers     Parlee     Forrest  $108,709.89
# 115175  Other Public Sector Employers     Udovic     Natasha  $129,807.63
# 115176  Other Public Sector Employers     Wagner  John Clyde  $168,230.79
# 115177  Other Public Sector Employers  Weisbrodt        Jorn  $207,692.37
# 115248  Other Public Sector Employers      Tanos     Antonia  $102,222.20
#
#        Tax Benefits                                           Employer  \
# 76671       $622.01                          King's University College
# 111692      $131.94                                   Colleges Ontario
# 113433           $-                                        Mitacs Inc.
# 113434           $-                                        Mitacs Inc.
# 115175      $867.92   Toronto Festival of Arts, Culture and Creativity
# 115176      $867.92   Toronto Festival of Arts, Culture and Creativity
# 115177    $1,272.92   Toronto Festival of Arts, Culture and Creativity
# 115248    $3,664.48  Toronto Organizing Committee for the 2015 Pan ...
#
#                                                 Job Title  Year
# 76671                                           Professor  2016
# 111692         Senior Manager, Finance And Administration  2016
# 113433  Director, Business Development & Team Lead Ont...  2016
# 113434                             Director, Partnerships  2017
# 115175            Senior Director, Corporate Partnerships  2016
# 115176                                 Executive Producer  2017
# 115177                                  Artistic Director  2018
# 115248  Senior Project Management Analyst / Analyste p...  2016

# %% [markdown]
# Looking at them, I'll assume that those were just typos and replace them all with 2015

# %%
df_Dict[2015]['Year']=2015

# %% [markdown]
# ### Standardize data by column
#
# Goal:
# <br>Standardize 'Sector', 'Last Name', 'First Name' and 'Employer' columns to title case
# <br>Standardize 'Salary' and 'Tax Benefits' columns to floats with a regex

# %%
for Year in range(1996,2021):
    for column in df_Dict[Year].columns:
        if column in ['Sector', 'Last Name', 'First Name', 'Employer','Job Title']:
            df_Dict[Year][column]=df_Dict[Year][column].str.title()
        elif column in ['Salary','Tax Benefits']:
            df_Dict[Year][column]=df_Dict[Year][column].str.replace(r'[^0-9.]', '',regex = True)
            
            
            
for Year in range(1996,2021):
    for column in df_Dict[Year].columns:
        if column in ['Salary','Tax Benefits']:
            try:
                df_Dict[Year][column]=df_Dict[Year][column].astype(float)
            except ValueError:
                print("Trouble in {}'s data in the {} column".format(Year,column))
# Out:
# Trouble in 2015's data in the Tax Benefits column
# Trouble in 2016's data in the Tax Benefits column

# %% [markdown]
# Check to see if there is data missing in the Tax Benefits columns in 2015 and 2016.

# %%
print('2015-Tax Benefits missing data =',len(df_Dict[2015][df_Dict[2015]['Tax Benefits']=='']))    
print('2016-Tax Benefits missing data =',len(df_Dict[2016][df_Dict[2016]['Tax Benefits']=='']))
# Out:
# 2015-Tax Benefits missing data = 6980
# 2016-Tax Benefits missing data = 1

# %% [markdown]
# It looks like a lot of rows without Tax Benefits data...not sure whether the values are just zero or actual missing data. I'll leave them as 'NaNs' for now and investigate further once I've put together all years.

# %%
#Change blank cells to NaNs
for Year in [2015,2016]:
    #Isolate affected rows
    Missing_Cells=df_Dict[Year][df_Dict[Year]['Tax Benefits'] == '']

    #Replace blank cells with NaN
    NaN_Fix=Missing_Cells['Tax Benefits'].replace('', np.NaN)

    #Replace new string in affected rows of 'Job Title Column'
    for index,value in NaN_Fix.items():
        df_Dict[Year].at[index,'Tax Benefits']=value

    print('{}-Tax Benefits blank data ='.format(Year),len(df_Dict[Year][df_Dict[Year]['Tax Benefits']=='']))
# Out:
# 2015-Tax Benefits blank data = 0
# 2016-Tax Benefits blank data = 0

# %% [markdown]
# Finally convert the Tax Benefits columns for 2015 and 2016 into floats

# %%
for Year in [2015,2016]:
    df_Dict[Year]['Tax Benefits']=df_Dict[Year]['Tax Benefits'].astype(float)

# %% [markdown]
# All columns in all years are consitent in formatting and data types. I'm ready to append them all together now.

# %% [markdown]
# ### Appending all DataFrames together

# %%
df_AllData=pd.DataFrame(columns=Clean_ColNames)  

for Year in range(1996,2021):
    df_AllData=df_AllData.append(df_Dict[Year])

# %%
df_AllData.sort_values(by=['Last Name','First Name','Sector','Employer'])
# Out:
#                                         Sector      Last Name First Name  \
# 112380                           School Boards         $1.00    Lisa Ann
# 17065       Government Of Ontario - Ministries         $1.00      Nicole
# 9201    Hydro One And Ontario Power Generation        A'Court     Adrian
# 22060   Hydro One And Ontario Power Generation        A'Court     Adrian
# 71764   Hydro One And Ontario Power Generation        A'Court     Adrian
# ...                                        ...            ...        ...
# 53487                             Universities  �Tongu�-Mayer      Raoul
# 53216                             Universities  �Tongu�-Mayer      Raoul
# 56165                             Universities  �Tongu�-Mayer      Raoul
# 126519                            Universities  �Tongu�-Mayer      Raoul
# 151792                            Universities  �Tongu�-Mayer      Raoul
#
#            Salary  Tax Benefits                               Employer  \
# 112380  125528.08       1445.62  Durham Catholic District School Board
# 17065   105222.39        144.83            Children And Youth Services
# 9201    103297.32          0.00               Ontario Power Generation
# 22060   104418.08       6097.20               Ontario Power Generation
# 71764   108870.60       6280.40               Ontario Power Generation
# ...           ...           ...                                    ...
# 53487   129729.00        729.48       Laurentian University Of Sudbury
# 53216   137401.50        758.81       Laurentian University Of Sudbury
# 56165   137774.48        763.13       Laurentian University Of Sudbury
# 126519  171843.35        477.63       Laurentian University Of Sudbury
# 151792  177520.98        348.55       Laurentian University Of Sudbury
#
#                                Job Title  Year
# 112380              Elementary Principal  2018
# 17065             Director, North Region  2018
# 9201    Electrician Foreman Construction  2005
# 22060   Electrician Foreman Construction  2009
# 71764   Electrician Foreman Construction  2011
# ...                                  ...   ...
# 53487                     Full Professor  2009
# 53216          Full Professor, Geography  2010
# 56165                     Full Professor  2011
# 126519                    Full Professor  2017
# 151792    Full Professor / Professeur(E)  2019
#
# [1676433 rows x 8 columns]

# %% [markdown]
# A quick look at the values sorted, I find the first 2 last names are numeric. I'll compare each of them with other similar first names, sectors and employers.

# %%
df_AllData[(df_AllData['First Name']=='Nicole')&
           (df_AllData['Sector']=='Government Of Ontario - Ministries')&
           (df_AllData['Employer']=='Children And Youth Services')].sort_values(by=['Last Name','First Name','Sector','Employer'])
# Out:
#                                    Sector Last Name First Name     Salary  \
# 17065  Government Of Ontario - Ministries    $1.00      Nicole  105222.39
# 13421  Government Of Ontario - Ministries      True     Nicole  124470.63
#
#        Tax Benefits                     Employer               Job Title  Year
# 17065        144.83  Children And Youth Services  Director, North Region  2018
# 13421        192.96  Children And Youth Services  Director, North Region  2016

# %%
df_AllData[(df_AllData['First Name']=='Lisa Ann')&
           (df_AllData['Sector']=='School Boards')&
           (df_AllData['Employer']=='Durham Catholic District School Board')].sort_values(by=['Last Name','First Name','Sector','Employer'])
# Out:
#                Sector Last Name First Name     Salary  Tax Benefits  \
# 112380  School Boards    $1.00    Lisa Ann  125528.08       1445.62
# 44653   School Boards      True   Lisa Ann  100400.48        228.72
# 46504   School Boards      True   Lisa Ann  101967.84        801.40
# 63831   School Boards      True   Lisa Ann  109875.71       1447.51
# 72331   School Boards      True   Lisa Ann  105470.04       1678.12
# 63593   School Boards      True   Lisa Ann  111577.80       1689.32
# 62750   School Boards      True   Lisa Ann  113575.43       1680.12
# 91117   School Boards      True   Lisa Ann  120123.12       1712.68
# 107247  School Boards      True   Lisa Ann  122483.73       1757.80
# 146284  School Boards      True   Lisa Ann  126709.59       1329.00
# 183448  School Boards      True   Lisa Ann  128072.10       1350.00
#
#                                      Employer                       Job Title  \
# 112380  Durham Catholic District School Board            Elementary Principal
# 44653   Durham Catholic District School Board  Elementary Teacher, Consultant
# 46504   Durham Catholic District School Board       Elementary Vice Principal
# 63831   Durham Catholic District School Board       Elementary Vice Principal
# 72331   Durham Catholic District School Board       Elementary Vice Principal
# 63593   Durham Catholic District School Board            Elementary Principal
# 62750   Durham Catholic District School Board            Elementary Principal
# 91117   Durham Catholic District School Board            Elementary Principal
# 107247  Durham Catholic District School Board            Elementary Principal
# 146284  Durham Catholic District School Board            Elementary Principal
# 183448  Durham Catholic District School Board            Elementary Principal
#
#         Year
# 112380  2018
# 44653   2010
# 46504   2011
# 63831   2012
# 72331   2013
# 63593   2014
# 62750   2015
# 91117   2016
# 107247  2017
# 146284  2019
# 183448  2020

# %% [markdown]
# It looks like they both shared the last name 'True'. I'll replace all $1.00 last names to 'True'.

# %%
#Changing $1.00 last names into 'True' 
df_AllData.loc[(df_AllData['First Name']=='Lisa Ann')&
               (df_AllData['Sector']=='School Boards')&
               (df_AllData['Employer']=='Durham Catholic District School Board'),'Last Name']='True'

df_AllData.loc[(df_AllData['First Name']=='Nicole')&
               (df_AllData['Sector']=='Government Of Ontario - Ministries')&
               (df_AllData['Employer']=='Children And Youth Services'),'Last Name']='True'

# %%
df_AllData.sort_values(by=['Last Name','First Name','Sector','Employer'])
# Out:
#                                         Sector      Last Name First Name  \
# 9201    Hydro One And Ontario Power Generation        A'Court     Adrian
# 22060   Hydro One And Ontario Power Generation        A'Court     Adrian
# 71764   Hydro One And Ontario Power Generation        A'Court     Adrian
# 30295   Hydro One And Ontario Power Generation        A'Court     Adrian
# 32103   Hydro One And Ontario Power Generation        A'Court     Adrian
# ...                                        ...            ...        ...
# 53487                             Universities  �Tongu�-Mayer      Raoul
# 53216                             Universities  �Tongu�-Mayer      Raoul
# 56165                             Universities  �Tongu�-Mayer      Raoul
# 126519                            Universities  �Tongu�-Mayer      Raoul
# 151792                            Universities  �Tongu�-Mayer      Raoul
#
#            Salary  Tax Benefits                          Employer  \
# 9201    103297.32          0.00          Ontario Power Generation
# 22060   104418.08       6097.20          Ontario Power Generation
# 71764   108870.60       6280.40          Ontario Power Generation
# 30295   108470.49       6214.75          Ontario Power Generation
# 32103   113376.06       6520.80          Ontario Power Generation
# ...           ...           ...                               ...
# 53487   129729.00        729.48  Laurentian University Of Sudbury
# 53216   137401.50        758.81  Laurentian University Of Sudbury
# 56165   137774.48        763.13  Laurentian University Of Sudbury
# 126519  171843.35        477.63  Laurentian University Of Sudbury
# 151792  177520.98        348.55  Laurentian University Of Sudbury
#
#                                Job Title  Year
# 9201    Electrician Foreman Construction  2005
# 22060   Electrician Foreman Construction  2009
# 71764   Electrician Foreman Construction  2011
# 30295   Electrician Foreman Construction  2012
# 32103   Electrician Foreman Construction  2013
# ...                                  ...   ...
# 53487                     Full Professor  2009
# 53216          Full Professor, Geography  2010
# 56165                     Full Professor  2011
# 126519                    Full Professor  2017
# 151792    Full Professor / Professeur(E)  2019
#
# [1676433 rows x 8 columns]

# %% [markdown]
# The issue has been fixed.

# %% [markdown]
# ### Condense 'Sector' Categories

# %%
print('Number of Sector Categories = {}'.format(len(set(df_AllData['Sector']))))
set(df_AllData['Sector'])
# Out:
# Number of Sector Categories = 73
# {'Colleges',
#  'Crown Agencies',
#  'Government Of Ontario - Judiciary',
#  'Government Of Ontario - Legislative Assembly & Offices',
#  'Government Of Ontario - Legislative Assembly And Offices',
#  'Government Of Ontario - Ministries',
#  'Government Of Ontario : Judiciary',
#  'Government Of Ontario : Legislative Assembly',
#  'Government Of Ontario : Legislative Assembly And Offices',
#  'Government Of Ontario : Ministries',
#  'Government Of Ontario — Judiciary',
#  'Government Of Ontario — Legislative Assembly And Offices',
#  'Government Of Ontario — Ministries',
#  'Hospitals',
#  'Hospitals & Boards Of Public Health',
#  'Hospitals And Boards Of Public Health',
#  'Hydro One & Ontario Power Generation',
#  'Hydro One And Ontario Power Generation',
#  'Municipalities',
#  'Municipalities & Services',
#  'Municipalities And Services',
#  'Ontario Power Generation',
#  'Ontario Public Service',
#  'Other Public Sector',
#  'Other Public Sector Employers',
#  'Other Public Sector Employers ',
#  'School Boards',
#  'Seconded (Advanced Education And Skills Development)*',
#  'Seconded (Attorney General)*',
#  'Seconded (Children & Youth Services)*',
#  'Seconded (Children And Youth Services)',
#  'Seconded (Children And Youth Services)*',
#  'Seconded (Children, Community And Social Services)',
#  'Seconded (Children, Community And Social Services)*',
#  'Seconded (Citizenship & Immigration)*',
#  'Seconded (Colleges And Universities)*',
#  'Seconded (Comm. Safety And Corr. Services)*',
#  'Seconded (Comm. Safety/Correctional�Srvcs.)*',
#  'Seconded (Community & Social Services)*',
#  'Seconded (Community And Social Services)*',
#  'Seconded (Community Safety & Correctional Services)*',
#  'Seconded (Community Safety And Correctional Services)*',
#  'Seconded (Community Safety/Correctional Srvcs.)*',
#  'Seconded (Economic Development & Trade)*',
#  'Seconded (Economic Development And Innovation)*',
#  'Seconded (Economic Development And Trade)*',
#  'Seconded (Education)',
#  'Seconded (Education)*',
#  'Seconded (Energy And Infrastructure)*',
#  'Seconded (Energy)*',
#  'Seconded (Environment)*',
#  'Seconded (Health & Long-Term Care)*',
#  'Seconded (Health & Long–Term Care)*',
#  'Seconded (Health And Long-Term Care)',
#  'Seconded (Health And Long-Term Care)*',
#  'Seconded (Health Promotion & Sport)*',
#  'Seconded (Health Promotion)*',
#  'Seconded (Health)*',
#  'Seconded (Labour)',
#  'Seconded (Labour)*',
#  'Seconded (Ministry Of Labour)*',
#  'Seconded (Municipal Affairs And Housing)*',
#  'Seconded (Research & Innovation)*',
#  'Seconded (Research And Innovation)*',
#  'Seconded (Solicitor General)',
#  'Seconded (Solicitor General)*',
#  'Seconded (Tourism, Culture & Sport)*',
#  'Seconded (Training, Colleges & Universities)*',
#  'Seconded (Training, Colleges And Universities)',
#  'Seconded (Training, Colleges And Universities)*',
#  'Seconded (Transportation)*',
#  'Universities',
#  'Universities - Universit�S'}

# %% [markdown]
# There are alot of sector categories and many of them seem to be repetitions of each other with minor changes in punctuation, spelling and abbreviation. I'll try to condense the categories simply by standardizing punctuation and spacing.

# %%
df_AllData['Sector']=df_AllData['Sector'].str.replace(':','-').str.replace('And','&').str.replace('*','',regex=True).str.replace('—','-')
df_AllData['Sector']=df_AllData['Sector'].str.rstrip().str.lstrip()

print('Number of Sector Categories = {}'.format(len(set(df_AllData['Sector']))))
# Out:
# Number of Sector Categories = 48

# %% [markdown]
# Reducing the sector categories from 73 to 48 is good, but I think I can do better.
#
# <br>I'll use fuzzy wuzzy to help group anymore strings that are similar keeping 75 as the threshold score

# %%
from fuzzywuzzy import fuzz

sectors_lst=sorted([sect for sect in set(df_AllData['Sector'])])

sect_group=[]

for sector in sectors_lst:
    for group in sect_group:
        if all(fuzz.partial_ratio(sector, string) > 75 for string in group):
            group.append(sector)
            break
    else:
        sect_group.append([sector, ])

        
groups_arr=[]
for group in sect_group:
    if len(group)>1:
        groups_arr.append(sorted(group,key=len))
        
groups_arr
# Out:
# [['Colleges',
#   'Seconded (Colleges & Universities)',
#   'Seconded (Training, Colleges & Universities)'],
#  ['Government Of Ontario - Judiciary',
#   'Government Of Ontario - Ministries',
#   'Government Of Ontario - Legislative Assembly',
#   'Government Of Ontario - Legislative Assembly & Offices'],
#  ['Hospitals', 'Hospitals & Boards Of Public Health'],
#  ['Ontario Power Generation', 'Hydro One & Ontario Power Generation'],
#  ['Municipalities', 'Municipalities & Services'],
#  ['Other Public Sector', 'Other Public Sector Employers'],
#  ['Seconded (Attorney General)', 'Seconded (Solicitor General)'],
#  ['Seconded (Community & Social Services)',
#   'Seconded (Children, Community & Social Services)'],
#  ['Seconded (Comm. Safety/Correctional�Srvcs.)',
#   'Seconded (Community Safety/Correctional Srvcs.)',
#   'Seconded (Community Safety & Correctional Services)'],
#  ['Seconded (Economic Development & Trade)',
#   'Seconded (Economic Development & Innovation)'],
#  ['Seconded (Energy)', 'Seconded (Energy & Infrastructure)'],
#  ['Seconded (Health)',
#   'Seconded (Health & Long-Term Care)',
#   'Seconded (Health & Long–Term Care)'],
#  ['Seconded (Health Promotion)', 'Seconded (Health Promotion & Sport)'],
#  ['Seconded (Labour)', 'Seconded (Tourism, Culture & Sport)'],
#  ['Universities', 'Universities - Universit�S']]

# %% [markdown]
# The grouping function did a good job, but there are still a few sectors that were included that probably don't belong together. I'll specify them and take them out of the list.
#
# Sectors to remove:
# <br>-'Colleges'
# <br>-'Government Of Ontario - Judiciary'
# <br>-'Government Of Ontario - Ministries'
# <br>-'Seconded (Attorney General)'
# <br>-'Seconded (Labour)'
#
#
# Finally, before condensing the sector names, I'll change **'Seconded (Comm. Safety/Correctional�Srvcs.)'** to **'Seconded (Community Safety & Correctional Services)'** because there're no special characters or abbreviations. I'll also append **'Seconded (Comm. Safety & Corr. Services)'** which seems to be similar to the group, but was left out.

# %%
sectors_to_remove=['Colleges','Government Of Ontario - Judiciary','Government Of Ontario - Ministries',
 'Seconded (Attorney General)','Seconded (Labour)']


for string in sectors_to_remove:
    for group in groups_arr:
        if string in group:
            group.remove(string)

same_sects_Dict={}            

for group in groups_arr:
    if len(group)>1:
        if group[0] == 'Seconded (Comm. Safety/Correctional�Srvcs.)':
            group.append('Seconded (Comm. Safety & Corr. Services)')
            same_sects_Dict['Seconded (Community Safety & Correctional Services)']=group
        else:
            same_sects_Dict[group[0]]=group
        
same_sects_Dict
# Out:
# {'Seconded (Colleges & Universities)': ['Seconded (Colleges & Universities)',
#   'Seconded (Training, Colleges & Universities)'],
#  'Government Of Ontario - Legislative Assembly': ['Government Of Ontario - Legislative Assembly',
#   'Government Of Ontario - Legislative Assembly & Offices'],
#  'Hospitals': ['Hospitals', 'Hospitals & Boards Of Public Health'],
#  'Ontario Power Generation': ['Ontario Power Generation',
#   'Hydro One & Ontario Power Generation'],
#  'Municipalities': ['Municipalities', 'Municipalities & Services'],
#  'Other Public Sector': ['Other Public Sector',
#   'Other Public Sector Employers'],
#  'Seconded (Community & Social Services)': ['Seconded (Community & Social Services)',
#   'Seconded (Children, Community & Social Services)'],
#  'Seconded (Community Safety & Correctional Services)': ['Seconded (Comm. Safety/Correctional�Srvcs.)',
#   'Seconded (Community Safety/Correctional Srvcs.)',
#   'Seconded (Community Safety & Correctional Services)',
#   'Seconded (Comm. Safety & Corr. Services)'],
#  'Seconded (Economic Development & Trade)': ['Seconded (Economic Development & Trade)',
#   'Seconded (Economic Development & Innovation)'],
#  'Seconded (Energy)': ['Seconded (Energy)',
#   'Seconded (Energy & Infrastructure)'],
#  'Seconded (Health)': ['Seconded (Health)',
#   'Seconded (Health & Long-Term Care)',
#   'Seconded (Health & Long–Term Care)'],
#  'Seconded (Health Promotion)': ['Seconded (Health Promotion)',
#   'Seconded (Health Promotion & Sport)'],
#  'Universities': ['Universities', 'Universities - Universit�S']}

# %%
for key, value in same_sects_Dict.items():
    for string in value:
        df_AllData['Sector']=df_AllData['Sector'].replace(string,key)
            
print('Number of Sector Categories = {}'.format(len(set(df_AllData['Sector']))))
# Out:
# Number of Sector Categories = 32

# %% [markdown]
# I've successfully condensed the categories from 73 to 32

# %% [markdown]
# ### Clearing NaNs in 'Tax Benefits'

# %% [markdown]
# #### 2016 Tax Benefit NaNs

# %%
df_AllData[(df_AllData['Tax Benefits'].isna())&(df_AllData['Year']==2016)]
# Out:
#                     Sector  Last Name First Name     Salary  Tax Benefits  \
# 84270  Other Public Sector  Malenfant      James  152545.47           NaN
#
#                                       Employer  \
# 84270  Independent Electricity System Operator
#
#                                                Job Title  Year
# 84270  Senior Analyst - Compliance And Dispute Resolu...  2016

# %% [markdown]
# I'll compare Mr. Malenfant's Tax Benefit data to other year to see if there is any consistency.

# %%
NaN_2016=df_AllData[(df_AllData['Tax Benefits'].isna())&(df_AllData['Year']==2016)]

df_AllData[(df_AllData['Last Name']==NaN_2016['Last Name'].values[0])&
           (df_AllData['First Name']==NaN_2016['First Name'].values[0])&
           (df_AllData['Sector']==NaN_2016['Sector'].values[0])]
# Out:
#                      Sector  Last Name First Name     Salary  Tax Benefits  \
# 112727  Other Public Sector  Malenfant      James  107325.45           NaN
# 84270   Other Public Sector  Malenfant      James  152545.47           NaN
# 94455   Other Public Sector  Malenfant      James  153909.53           0.0
# 104339  Other Public Sector  Malenfant      James  155282.66           0.0
# 114650  Other Public Sector  Malenfant      James  158596.56           0.0
#
#                                                  Employer  \
# 112727            Independent Electricity System Operator
# 84270             Independent Electricity System Operator
# 94455   Independent Electricity System Operator / Op�R...
# 104339            Independent Electricity System Operator
# 114650            Independent Electricity System Operator
#
#                                                 Job Title  Year
# 112727  Senior Analyst - Compliance & Dispute Resoluti...  2015
# 84270   Senior Analyst - Compliance And Dispute Resolu...  2016
# 94455   Senior Analyst, Compliance And Dispute Resolut...  2017
# 104339  Senior Analyst - Compliance And Dispute Resolu...  2018
# 114650  Senior Analyst - Compliance And Dispute Resolu...  2019

# %% [markdown]
# Looks like the tax benefits for Mr. Malenfant were consistently 0 in other years

# %%
#Make all of Mr. Malenfant's NaN Tax Benefit data 0
df_AllData.loc[(df_AllData['Last Name']==NaN_2016['Last Name'].values[0])&
               (df_AllData['First Name']==NaN_2016['First Name'].values[0])&
               (df_AllData['Sector']==NaN_2016['Sector'].values[0]),'Tax Benefits']=0.0


df_AllData[(df_AllData['Last Name']==NaN_2016['Last Name'].values[0])&
           (df_AllData['First Name']==NaN_2016['First Name'].values[0])&
           (df_AllData['Sector']==NaN_2016['Sector'].values[0])]
# Out:
#                      Sector  Last Name First Name     Salary  Tax Benefits  \
# 112727  Other Public Sector  Malenfant      James  107325.45           0.0
# 84270   Other Public Sector  Malenfant      James  152545.47           0.0
# 94455   Other Public Sector  Malenfant      James  153909.53           0.0
# 104339  Other Public Sector  Malenfant      James  155282.66           0.0
# 114650  Other Public Sector  Malenfant      James  158596.56           0.0
#
#                                                  Employer  \
# 112727            Independent Electricity System Operator
# 84270             Independent Electricity System Operator
# 94455   Independent Electricity System Operator / Op�R...
# 104339            Independent Electricity System Operator
# 114650            Independent Electricity System Operator
#
#                                                 Job Title  Year
# 112727  Senior Analyst - Compliance & Dispute Resoluti...  2015
# 84270   Senior Analyst - Compliance And Dispute Resolu...  2016
# 94455   Senior Analyst, Compliance And Dispute Resolut...  2017
# 104339  Senior Analyst - Compliance And Dispute Resolu...  2018
# 114650  Senior Analyst - Compliance And Dispute Resolu...  2019

# %% [markdown]
# #### 2015 Tax Benefit NaNs

# %%
df_AllData[(df_AllData['Tax Benefits'].isna())&(df_AllData['Year']==2015)]
# Out:
#                                     Sector     Last Name First Name  \
# 75      Government Of Ontario - Ministries      Elworthy      Glenn
# 127     Government Of Ontario - Ministries         Mills     Donald
# 201     Government Of Ontario - Ministries        Andrew     Nelson
# 272     Government Of Ontario - Ministries        Beaton      Emily
# 310     Government Of Ontario - Ministries     Blutstein      Heidi
# ...                                    ...           ...        ...
# 115885                Seconded (Education)       Robbins      Carla
# 115895                Seconded (Education)  Sidhu-Thomas     Satbir
# 115897                Seconded (Education)  Slack Miller      Susan
# 115900                Seconded (Education)    Steinhauer      Nancy
# 115906                Seconded (Education)    Vandermeer      Sonja
#
#            Salary  Tax Benefits                                  Employer  \
# 75      100739.91           NaN         Agriculture, Food & Rural Affairs
# 127     101404.04           NaN         Agriculture, Food & Rural Affairs
# 201     104617.60           NaN                          Attorney General
# 272     118001.74           NaN                          Attorney General
# 310     150051.65           NaN                          Attorney General
# ...           ...           ...                                       ...
# 115885  113092.75           NaN             Toronto District School Board
# 115895  119495.67           NaN             Toronto District School Board
# 115897  100956.24           NaN             Toronto District School Board
# 115900  128031.10           NaN             Toronto District School Board
# 115906  101814.96           NaN  Trillium Lakelands District School Board
#
#                                                 Job Title  Year
# 75      Meat Hygiene Officer / Agent De L'Hygiène Des ...  2015
# 127             Policy Advisor / Conseiller En Politiques  2015
# 201                              Investigator / Enquêteur  2015
# 272     Assistant Crown Attorney / Procureure Adjointe...  2015
# 310                                     Counsel / Avocate  2015
# ...                                                   ...   ...
# 115885             Education Officer / Agente D'Éducation  2015
# 115895              Education Officer / Agent D'Éducation  2015
# 115897             Education Officer / Agente D'Éducation  2015
# 115900  Student Achievement Officer / Agente Du Rendem...  2015
# 115906             Education Officer / Agente D'Éducation  2015
#
# [6979 rows x 8 columns]

# %% [markdown]
# There are very many rows with NaN. I'll take a random sample (10%) of rows and find the mean tax benefit value from 2014 and 2016 for those individuals.

# %%
NaN_2015=df_AllData[(df_AllData['Tax Benefits'].isna())&(df_AllData['Year']==2015)]

Sample_NaN_2015=NaN_2015.sample(frac=0.1)

# %% [markdown]
# I'll create a quick pie plot to see how they are distributred.

# %%
import matplotlib.pyplot as plt


#initialize dict to bin value counts
vals_Dict={}
bin_names=['Zero','1-100','101-1000','1000+']
for i in bin_names:
    vals_Dict[i]=0

    
    
for i in range(len(Sample_NaN_2015)):
    
    df_OtherYears=df_AllData[(df_AllData['Last Name']==Sample_NaN_2015['Last Name'].values[i])&
                             (df_AllData['First Name']==Sample_NaN_2015['First Name'].values[i])&
                             (df_AllData['Sector']==Sample_NaN_2015['Sector'].values[i])&
                             (df_AllData['Year'].between(2014,2016))]

    #num is the average of the 2014 and 2016 Tax Benefits values
    if len(df_OtherYears) == 3:
        num=(df_OtherYears['Tax Benefits'].iloc[0]+df_OtherYears['Tax Benefits'].iloc[-1])/2

        if num == 0:
            vals_Dict['Zero']+=1
        elif (num>0) & (num<=100):
            vals_Dict['1-100']+=1
        elif (num>100) & (num<=1000):
            vals_Dict['101-1000']+=1
        elif num>1000:
            vals_Dict['1000+']+=1

# %%
labels = []
counts = []

for x, y in vals_Dict.items():
    labels.append(x)
    counts.append(y)

plt.pie(counts, labels=labels,autopct='%1.1f%%')

plt.axis('equal')
plt.show()

# %% [markdown]
# It looks like over 60% of the 2014 and 2016 data averaged out to 0 from the sample. This leaves evidence that we can set the NaNs in the 2015 dataset to 0.

# %%
#Set all NaNs in the 2015 set to 0

df_AllData.loc[(df_AllData['Tax Benefits'].isna())&(df_AllData['Year']==2015),'Tax Benefits']=0.0

# %% [markdown]
# My DataFrame is now clean and ready for some EDA.

# %%
df_AllData.to_csv('1996_2020_SunshineList.csv',index=False)
